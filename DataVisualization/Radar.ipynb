# %%
from pyecharts.charts import Radar
from pyecharts import options as opts
from pyecharts.faker import Faker
from pyecharts.globals import ThemeType

from pyecharts.globals import CurrentConfig,NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

# %%
v1=[[4300,10000,28000,35000,50000,19000]]                      
v2=[[5000,14000,28000,31000,42000,21000]]

# %%
c = (
    Radar()
    .add_schema(
        schema=[
            opts.RadarIndicatorItem(name='项目1',max_=6000),
            opts.RadarIndicatorItem(name='项目2',max_=16000),
            opts.RadarIndicatorItem(name='项目3',max_=30000),
            opts.RadarIndicatorItem(name='项目4',max_=38000),
            opts.RadarIndicatorItem(name='项目5',max_=60000),
            opts.RadarIndicatorItem(name='项目6',max_=22000),
            
        ]
    )
    .add('数据1',v1,color='blue')
    .add('数据2',v2,color='green')
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
)
c.load_javascript()

# %%
c.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="32205a9c0b3745c4a5fbbac2469da164" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_32205a9c0b3745c4a5fbbac2469da164 = echarts.init(
#             document.getElementById('32205a9c0b3745c4a5fbbac2469da164'), 'white', {renderer: 'canvas'});
#         var option_32205a9c0b3745c4a5fbbac2469da164 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u6570\u636e1",
#             "data": [
#                 [
#                     4300,
#                     10000,
#                     28000,
#                     35000,
#                     50000,
#                     19000
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "selectedMode": false,
#             "zlevel": 0,
#             "z": 2,
#             "itemStyle": {
#                 "normal": {
#                     "color": "blue"
#                 }
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u6570\u636e2",
#             "data": [
#                 [
#                     5000,
#                     14000,
#                     28000,
#                     31000,
#                     42000,
#                     21000
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "selectedMode": false,
#             "zlevel": 0,
#             "z": 2,
#             "itemStyle": {
#                 "normal": {
#                     "color": "green"
#                 }
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6570\u636e1",
#                 "\u6570\u636e2"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "radar": [
#         {
#             "indicator": [
#                 {
#                     "name": "\u9879\u76ee1",
#                     "max": 6000
#                 },
#                 {
#                     "name": "\u9879\u76ee2",
#                     "max": 16000
#                 },
#                 {
#                     "name": "\u9879\u76ee3",
#                     "max": 30000
#                 },
#                 {
#                     "name": "\u9879\u76ee4",
#                     "max": 38000
#                 },
#                 {
#                     "name": "\u9879\u76ee5",
#                     "max": 60000
#                 },
#                 {
#                     "name": "\u9879\u76ee6",
#                     "max": 22000
#                 }
#             ],
#             "startAngle": 90,
#             "name": {
#                 "textStyle": {}
#             },
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "areaStyle": {
#                     "opacity": 0
#                 }
#             },
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             }
#         }
#     ]
# };
#         chart_32205a9c0b3745c4a5fbbac2469da164.setOption(option_32205a9c0b3745c4a5fbbac2469da164);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 折线图

# %%
from pyecharts.charts import Line

# %%
c=(
    Line()
    .add_xaxis(Faker.choose())

    .add_yaxis('商家A',Faker.values()) # 折线
    .add_yaxis('商家B',Faker.values(),is_smooth=True) # 平滑

    .set_global_opts(
        title_opts=opts.TitleOpts(title='折线图'),
        tooltip_opts=opts.TooltipOpts(trigger='axis') # 图像移动的时候有条竖线
                    )
)
c.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="ee7981743cfa48fa8ebe8b03d0263a28" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_ee7981743cfa48fa8ebe8b03d0263a28 = echarts.init(
#             document.getElementById('ee7981743cfa48fa8ebe8b03d0263a28'), 'white', {renderer: 'canvas'});
#         var option_ee7981743cfa48fa8ebe8b03d0263a28 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     31
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     21
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     84
#                 ],
#                 [
#                     "\u5468\u56db",
#                     91
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     27
#                 ],
#                 [
#                     "\u5468\u516d",
#                     22
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     78
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     43
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     98
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     139
#                 ],
#                 [
#                     "\u5468\u56db",
#                     119
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     54
#                 ],
#                 [
#                     "\u5468\u516d",
#                     105
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     92
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u6298\u7ebf\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_ee7981743cfa48fa8ebe8b03d0263a28.setOption(option_ee7981743cfa48fa8ebe8b03d0263a28);
#     </script>
# </body>
# </html>

# %%
c=(
    Line(
        init_opts=opts.InitOpts(
            width='800px',
            height='500px'
        )
    )
    .add_xaxis(xaxis_data=Faker.week)
    
    .add_yaxis(
        '商家A',
        y_axis=[120,200,150,250,42,551,421],
        symbol='triangle',
        symbol_size=20,

        # 线条样式
        linestyle_opts=opts.LineStyleOpts(
            color='green',
            width=2,
            type_='dashed'# 虚线
        ),
        # 标签
        label_opts=opts.LabelOpts(is_show=False),

        # 点的属性
        itemstyle_opts=opts.ItemStyleOpts(
            border_width=2,
            border_color='yellow',
            color='blue',
            
            
        ),
        # 标注点
        markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_='max'),
                opts.MarkPointItem(type_='min'),
            ]
        ),
        markline_opts=opts.MarkLineOpts(
            data=[
                opts.MarkLineItem(type_='average'), # 平均线
            ]
        )
        
        
    ) # 折线
    .set_global_opts(
        yaxis_opts=opts.AxisOpts(
            type_='value', # 
            splitarea_opts=opts.SplitLineOpts(is_show=True) # 分割线 平行于x轴的
        ),
        tooltip_opts=opts.TooltipOpts(trigger='axis') # 图像移动的时候有条竖线
    )
    

)
c.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="b4f165172eda4456b7b580effc1adf2b" class="chart-container" style="width:800px; height:500px; "></div>
#     <script>
#         var chart_b4f165172eda4456b7b580effc1adf2b = echarts.init(
#             document.getElementById('b4f165172eda4456b7b580effc1adf2b'), 'white', {renderer: 'canvas'});
#         var option_b4f165172eda4456b7b580effc1adf2b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "triangle",
#             "symbolSize": 20,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     120
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     200
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     150
#                 ],
#                 [
#                     "\u5468\u56db",
#                     250
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     42
#                 ],
#                 [
#                     "\u5468\u516d",
#                     551
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     421
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 2,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "dashed",
#                 "color": "green"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "type": "max"
#                     },
#                     {
#                         "type": "min"
#                     }
#                 ]
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "type": "average"
#                     }
#                 ]
#             },
#             "itemStyle": {
#                 "color": "blue",
#                 "borderColor": "yellow",
#                 "borderWidth": 2
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_b4f165172eda4456b7b580effc1adf2b.setOption(option_b4f165172eda4456b7b580effc1adf2b);
#     </script>
# </body>
# </html>

# %% [markdown]
# ##  面积图

# %%
x_data=['周一','周二','周三','周四','周五','周六','周日']
y_data=[820,932,901,934,1290,1330,1320]

# %%
c = (
    Line()
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        '',
        y_axis=y_data,
        areastyle_opts=opts.AreaStyleOpts(opacity=0.8))
    
    .set_global_opts(
        title_opts=opts.TitleOpts(title='面积图'),
        tooltip_opts=opts.TooltipOpts(trigger='axis'),

        # boundary_gap 和 y轴没有间隙
        xaxis_opts=opts.AxisOpts(type_='category',boundary_gap=False)
    )
)
c.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="7976fd6fd33e4f1391b857178642544e" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_7976fd6fd33e4f1391b857178642544e = echarts.init(
#             document.getElementById('7976fd6fd33e4f1391b857178642544e'), 'white', {renderer: 'canvas'});
#         var option_7976fd6fd33e4f1391b857178642544e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     820
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     932
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     901
#                 ],
#                 [
#                     "\u5468\u56db",
#                     934
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     1290
#                 ],
#                 [
#                     "\u5468\u516d",
#                     1330
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     1320
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.8
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": false,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u9762\u79ef\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_7976fd6fd33e4f1391b857178642544e.setOption(option_7976fd6fd33e4f1391b857178642544e);
#     </script>
# </body>
# </html>

# %% [markdown]
# ##  堆叠面积图

# %%
c = (
    Line()
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        '广告',
        stack='堆叠',
        y_axis=[120,40,60,50,45,65,84],
        areastyle_opts=opts.AreaStyleOpts(opacity=0.8),
        label_opts=opts.LabelOpts(is_show=False)
    )
    .add_yaxis(
        '销售',
        stack='堆叠',
        y_axis=[120,40,60,50,45,65,84],
        areastyle_opts=opts.AreaStyleOpts(opacity=0.8),
        label_opts=opts.LabelOpts(is_show=False)
    )
    .add_yaxis(
        '浏览',
        stack='堆叠',
        y_axis=[120,40,60,50,45,65,84],
        areastyle_opts=opts.AreaStyleOpts(opacity=0.8),
        label_opts=opts.LabelOpts(is_show=False)
    )
    
    .set_global_opts(
        title_opts=opts.TitleOpts(title='堆叠面积图'),
        tooltip_opts=opts.TooltipOpts(trigger='axis'),

        # boundary_gap 和 y轴没有间隙
        xaxis_opts=opts.AxisOpts(type_='category',boundary_gap=False)
    )
)
c.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="10faca2f12414580a228b6792b3e67b3" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_10faca2f12414580a228b6792b3e67b3 = echarts.init(
#             document.getElementById('10faca2f12414580a228b6792b3e67b3'), 'white', {renderer: 'canvas'});
#         var option_10faca2f12414580a228b6792b3e67b3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5e7f\u544a",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stack": "\u5806\u53e0",
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     120
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     40
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     60
#                 ],
#                 [
#                     "\u5468\u56db",
#                     50
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     45
#                 ],
#                 [
#                     "\u5468\u516d",
#                     65
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     84
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.8
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u9500\u552e",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stack": "\u5806\u53e0",
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     120
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     40
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     60
#                 ],
#                 [
#                     "\u5468\u56db",
#                     50
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     45
#                 ],
#                 [
#                     "\u5468\u516d",
#                     65
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     84
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.8
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u6d4f\u89c8",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stack": "\u5806\u53e0",
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     120
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     40
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     60
#                 ],
#                 [
#                     "\u5468\u56db",
#                     50
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     45
#                 ],
#                 [
#                     "\u5468\u516d",
#                     65
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     84
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.8
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u544a",
#                 "\u9500\u552e",
#                 "\u6d4f\u89c8"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": false,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d
